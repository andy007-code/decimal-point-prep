# %% [markdown]
# # Python Setup — Week 1
# **Aayan Mulani | Decimal Point Analytics Preparation**
#
# This notebook confirms the environment is working correctly and covers the very basics of Python: printing output and performing arithmetic. These are the building blocks every subsequent notebook builds on.

# %% [markdown]
# ## 1. Environment Check
# Before doing any analysis, we verify that Python and Jupyter Notebook are running correctly. The cell below is the traditional first program in any language — if it prints successfully, the environment is ready.

# %%
print('Hello, Decimal Point!')
# Out:
# Hello, Decimal Point!

# %% [markdown]
# ## 2. Basic Arithmetic
# Python supports all standard mathematical operations. Understanding operator precedence (BODMAS) is important — Python follows the same rules as mathematics.
#
# | Operator | Meaning | Example |
# |---|---|---|
# | `+` | Addition | `5 + 3 = 8` |
# | `-` | Subtraction | `5 - 3 = 2` |
# | `*` | Multiplication | `5 * 3 = 15` |
# | `/` | Division | `5 / 3 = 1.667` |
# | `**` | Power / Exponent | `5 ** 3 = 125` |
# | `//` | Floor Division | `5 // 3 = 1` |
# | `%` | Modulo (remainder) | `5 % 3 = 2` |

# %%
print(5 + 3)
print(5 - 3)
print(5 * 3)
print(5 / 3)
print(5 ** 3)   # 5 to the power of 3
print(5 // 3)   # integer division — drops the decimal
print(5 % 3)    # remainder after division
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 125
# 1
# 2

# %% [markdown]
# ### Financial Application
# Arithmetic operations are the foundation of every financial formula. For example, calculating the value of an investment after one year of growth:

# %%
principal = 100000    # Rs 1 lakh invested
rate = 0.085          # 8.5% annual interest rate
years = 1

final_value = principal * (1 + rate) ** years
print(f'Investment grows to: Rs {final_value:,.2f}')
# Out:
# Investment grows to: Rs 108,500.00
