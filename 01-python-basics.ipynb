# %%
x = 10
y = 3
print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x ** y)
print(x // y)
print(x % y)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1000
# 3
# 1

# %%
name = "Aayan"
age = 22
print("My name is", name, "and I am", age, "years old")
# Out:
# My name is Aayan and I am 22 years old

# %%
def add_numbers(a, b):
    result = a + b
    return result

print(add_numbers(10, 20))
print(add_numbers(100,250))
# Out:
# 30
# 350

# %%
def greet(name):
    message = "Hello " + name + ", welcome to Decimal Point!"
    return message

print(greet("Aayan"))
# Out:
# Hello Aayan, welcome to Decimal Point!

# %%
def simple_interset(p, r, n):
    interset = (p*r*n) / 100
    return interset

print(simple_interset(100000, 8.5, 3))
# Out:
# 25500.0

# %%
x = 10
print(x > 5)
print(x == 10)
print(x != 3)
# Out:
# True
# True
# True

# %%
marks = 85

if marks >=90:
    print("Grade A")
elif marks >=75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
stock_return = 2.5

if stock_return > 0:
    print("Positive day — stock went up")
elif stock_return == 0:
    print("Flat day — no movement")
else:
    print("Negative day — stock went down")
# Out:
# Positive day — stock went up

# %%
prices = [100, 102, 98, 105, 110, 108, 112]
print(prices[0])
print(prices[-1])
print(prices[2:5])
# Out:
# 100
# 112
# [98, 105, 110]
